# %% [markdown]
# # VMware Documentation Analysis Experiment
#
# 이 노트북은 단일 쿼리에 대한 모델의 분석 결과를 실행하고 시각화합니다.

# %%
import os
import pandas as pd
import subprocess
from IPython.display import display, Markdown

# 프로젝트 루트 경로 확인
project_root = os.getcwd()
log_path = os.path.join(project_root, "results", "experiment_log.csv")

print(f"현재 작업 디렉토리: {project_root}")
print(f"로그 파일 경로: {log_path}")
# Out:
# 현재 작업 디렉토리: /home/remote/jwoo/THU/Capstone
# 로그 파일 경로: /home/remote/jwoo/THU/Capstone/results/experiment_log.csv

# %%
def run_experiment_script():
    # 현재 환경 변수 가져오기
    env = os.environ.copy()
    # PYTHONPATH에 현재 작업 디렉토리(프로젝트 루트) 추가
    env["PYTHONPATH"] = os.getcwd()
    
    # 파이썬 실행 경로 설정
    cmd = ["python", "src/main.py"]
    
    print("🚀 실험 스크립트 실행 중 (PYTHONPATH 설정 완료)...\n")
    
    # 프로세스 시작
    process = subprocess.Popen(
        cmd, 
        stdout=subprocess.PIPE, 
        stderr=subprocess.STDOUT, 
        text=True, 
        encoding='utf-8',
        env=env # 수정된 환경 변수 전달
    )

    # 실시간 로그 출력
    if process.stdout:
        for line in iter(process.stdout.readline, ""):
            print(line, end="")
    
    process.wait()
    
    if process.returncode == 0:
        print("\n✅ 실험이 성공적으로 완료되었습니다.")
    else:
        print(f"\n❌ 실험 중 오류가 발생했습니다. (Return Code: {process.returncode})")

# 실험 실행
run_experiment_script()
# Out:
# 🚀 실험 스크립트 실행 중 (PYTHONPATH 설정 완료)...
#
# === Long Context LLM Experiment Runner v3 ===
#
# [Experiment] VMware Documentation
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/103 [00:00<00:00, 9362.29it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   1%|          | 1/103 [00:00<00:00, 4148.67it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   2%|▏         | 2/103 [00:00<00:00, 3571.14it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   2%|▏         | 2/103 [00:00<00:00, 2931.03it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   3%|▎         | 3/103 [00:00<00:00, 3293.09it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   3%|▎         | 3/103 [00:00<00:00, 2949.58it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   4%|▍         | 4/103 [00:00<00:00, 2855.70it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   4%|▍         | 4/103 [00:00<00:00, 2645.00it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   5%|▍         | 5/103 [00:00<00:00, 2789.88it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   5%|▍         | 5/103 [00:00<00:00, 2633.95it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   6%|▌         | 6/103 [00:00<00:00, 2719.75it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   6%|▌         | 6/103 [00:00<00:00, 2475.98it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 7/103 [00:00<00:00, 2572.74it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 7/103 [00:00<00:00, 2474.31it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 8/103 [00:00<00:00, 2532.03it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   8%|▊         | 8/103 [00:00<00:00, 2447.80it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   9%|▊         | 9/103 [00:00<00:00, 2482.16it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   9%|▊         | 9/103 [00:00<00:00, 2410.37it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:  10%|▉         | 10/103 [00:00<00:00, 1492.16it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:  10%|▉         | 10/103 [00:00<00:00, 1466.64it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:  11%|█         | 11/103 [00:00<00:00, 1534.08it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:  11%|█         | 11/103 [00:00<00:00, 1487.39it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:  12%|█▏        | 12/103 [00:00<00:00, 1555.80it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:  12%|█▏        | 12/103 [00:00<00:00, 1532.17it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:  13%|█▎        | 13/103 [00:00<00:00, 1556.55it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:  13%|█▎        | 13/103 [00:00<00:00, 1535.94it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:  14%|█▎        | 14/103 [00:00<00:00, 1608.64it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:  14%|█▎        | 14/103 [00:00<00:00, 1589.74it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:  15%|█▍        | 15/103 [00:00<00:00, 1551.91it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:  15%|█▍        | 15/103 [00:00<00:00, 1531.70it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:  16%|█▌        | 16/103 [00:00<00:00, 1490.55it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:  16%|█▌        | 16/103 [00:00<00:00, 1474.63it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:  17%|█▋        | 17/103 [00:00<00:00, 1467.90it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 17/103 [00:00<00:00, 1452.20it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 18/103 [00:00<00:00, 1483.25it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  17%|█▋        | 18/103 [00:00<00:00, 1468.94it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  18%|█▊        | 19/103 [00:00<00:00, 1302.83it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  18%|█▊        | 19/103 [00:00<00:00, 1292.40it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  19%|█▉        | 20/103 [00:00<00:00, 1331.53it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  19%|█▉        | 20/103 [00:00<00:00, 1321.91it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  20%|██        | 21/103 [00:00<00:00, 1355.40it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  20%|██        | 21/103 [00:00<00:00, 1345.95it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  21%|██▏       | 22/103 [00:00<00:00, 1355.84it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  21%|██▏       | 22/103 [00:00<00:00, 1339.72it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  22%|██▏       | 23/103 [00:00<00:00, 1374.61it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  22%|██▏       | 23/103 [00:00<00:00, 1364.91it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  23%|██▎       | 24/103 [00:00<00:00, 1396.55it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  23%|██▎       | 24/103 [00:00<00:00, 1380.25it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  24%|██▍       | 25/103 [00:00<00:00, 1410.19it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  24%|██▍       | 25/103 [00:00<00:00, 1401.61it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  25%|██▌       | 26/103 [00:00<00:00, 1432.78it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  25%|██▌       | 26/103 [00:00<00:00, 1424.44it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  26%|██▌       | 27/103 [00:00<00:00, 1449.55it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  26%|██▌       | 27/103 [00:00<00:00, 1440.39it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  27%|██▋       | 28/103 [00:00<00:00, 1465.50it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  27%|██▋       | 28/103 [00:00<00:00, 1456.95it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  28%|██▊       | 29/103 [00:00<00:00, 1460.34it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  28%|██▊       | 29/103 [00:00<00:00, 1449.74it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  29%|██▉       | 30/103 [00:00<00:00, 1480.97it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  29%|██▉       | 30/103 [00:00<00:00, 1469.37it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  30%|███       | 31/103 [00:00<00:00, 1495.69it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  30%|███       | 31/103 [00:00<00:00, 1487.92it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  31%|███       | 32/103 [00:00<00:00, 1461.64it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  31%|███       | 32/103 [00:00<00:00, 1452.20it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  32%|███▏      | 33/103 [00:00<00:00, 1473.77it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  32%|███▏      | 33/103 [00:00<00:00, 1466.49it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  33%|███▎      | 34/103 [00:00<00:00, 1491.39it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  33%|███▎      | 34/103 [00:00<00:00, 1482.30it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  34%|███▍      | 35/103 [00:00<00:00, 1505.42it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  34%|███▍      | 35/103 [00:00<00:00, 1494.56it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  35%|███▍      | 36/103 [00:00<00:00, 1518.12it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  35%|███▍      | 36/103 [00:00<00:00, 1508.17it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  36%|███▌      | 37/103 [00:00<00:00, 1529.40it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  36%|███▌      | 37/103 [00:00<00:00, 1519.78it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  37%|███▋      | 38/103 [00:00<00:00, 1347.12it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  37%|███▋      | 38/103 [00:00<00:00, 1338.89it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  38%|███▊      | 39/103 [00:00<00:00, 1359.04it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  38%|███▊      | 39/103 [00:00<00:00, 1353.74it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  39%|███▉      | 40/103 [00:00<00:00, 1372.99it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  39%|███▉      | 40/103 [00:00<00:00, 1367.80it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  40%|███▉      | 41/103 [00:00<00:00, 1385.88it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  40%|███▉      | 41/103 [00:00<00:00, 1380.86it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  41%|████      | 42/103 [00:00<00:00, 1400.77it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  41%|████      | 42/103 [00:00<00:00, 1394.45it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  42%|████▏     | 43/103 [00:00<00:00, 1409.46it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  42%|████▏     | 43/103 [00:00<00:00, 1403.63it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  43%|████▎     | 44/103 [00:00<00:00, 1421.86it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  43%|████▎     | 44/103 [00:00<00:00, 1416.45it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  44%|████▎     | 45/103 [00:00<00:00, 1427.66it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  44%|████▎     | 45/103 [00:00<00:00, 1422.29it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  45%|████▍     | 46/103 [00:00<00:00, 1440.09it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  45%|████▍     | 46/103 [00:00<00:00, 1435.10it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 1446.70it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 1441.72it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 1458.61it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 1346.28it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 1363.90it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 1358.23it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 1365.50it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 1361.29it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 1376.69it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 1372.59it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 1386.62it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 1382.69it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1397.96it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1393.83it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1407.57it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1403.59it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1418.76it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1413.72it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1384.41it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1380.42it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1393.07it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1389.31it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1401.24it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1397.45it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  57%|█████▋    | 59/103 [00:00<00:00, 1409.74it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  57%|█████▋    | 59/103 [00:00<00:00, 1406.10it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  58%|█████▊    | 60/103 [00:00<00:00, 1316.60it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  58%|█████▊    | 60/103 [00:00<00:00, 1271.95it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  59%|█████▉    | 61/103 [00:00<00:00, 1280.06it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  59%|█████▉    | 61/103 [00:00<00:00, 1276.10it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  60%|██████    | 62/103 [00:00<00:00, 1288.73it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  60%|██████    | 62/103 [00:00<00:00, 1285.78it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  61%|██████    | 63/103 [00:00<00:00, 1295.45it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  61%|██████    | 63/103 [00:00<00:00, 1291.43it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  62%|██████▏   | 64/103 [00:00<00:00, 1303.02it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  62%|██████▏   | 64/103 [00:00<00:00, 1300.16it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  63%|██████▎   | 65/103 [00:00<00:00, 1311.38it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  63%|██████▎   | 65/103 [00:00<00:00, 1308.54it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  64%|██████▍   | 66/103 [00:00<00:00, 1320.59it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  64%|██████▍   | 66/103 [00:00<00:00, 1317.81it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  65%|██████▌   | 67/103 [00:00<00:00, 1326.92it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  65%|██████▌   | 67/103 [00:00<00:00, 1324.07it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  66%|██████▌   | 68/103 [00:00<00:00, 1277.70it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  66%|██████▌   | 68/103 [00:00<00:00, 1273.54it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  67%|██████▋   | 69/103 [00:00<00:00, 1283.79it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  67%|██████▋   | 69/103 [00:00<00:00, 1281.07it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  68%|██████▊   | 70/103 [00:00<00:00, 1292.63it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  68%|██████▊   | 70/103 [00:00<00:00, 1290.04it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  69%|██████▉   | 71/103 [00:00<00:00, 1299.25it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  69%|██████▉   | 71/103 [00:00<00:00, 1296.00it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  70%|██████▉   | 72/103 [00:00<00:00, 1307.05it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  70%|██████▉   | 72/103 [00:00<00:00, 1304.48it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  71%|███████   | 73/103 [00:00<00:00, 1313.00it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  71%|███████   | 73/103 [00:00<00:00, 1309.85it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  72%|███████▏  | 74/103 [00:00<00:00, 1321.94it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  72%|███████▏  | 74/103 [00:00<00:00, 1319.47it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  73%|███████▎  | 75/103 [00:00<00:00, 1328.26it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  73%|███████▎  | 75/103 [00:00<00:00, 1325.68it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  74%|███████▍  | 76/103 [00:00<00:00, 1324.59it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  74%|███████▍  | 76/103 [00:00<00:00, 1321.94it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  75%|███████▍  | 77/103 [00:00<00:00, 1333.11it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  75%|███████▍  | 77/103 [00:00<00:00, 1330.62it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  76%|███████▌  | 78/103 [00:00<00:00, 1342.51it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  76%|███████▌  | 78/103 [00:00<00:00, 1340.14it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  77%|███████▋  | 79/103 [00:00<00:00, 1349.96it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  77%|███████▋  | 79/103 [00:00<00:00, 1347.51it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  78%|███████▊  | 80/103 [00:00<00:00, 1356.61it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  78%|███████▊  | 80/103 [00:00<00:00, 1354.17it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  79%|███████▊  | 81/103 [00:00<00:00, 1363.03it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  79%|███████▊  | 81/103 [00:00<00:00, 1360.57it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  80%|███████▉  | 82/103 [00:00<00:00, 1297.62it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  80%|███████▉  | 82/103 [00:00<00:00, 1294.08it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  81%|████████  | 83/103 [00:00<00:00, 1304.69it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  81%|████████  | 83/103 [00:00<00:00, 1301.79it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  82%|████████▏ | 84/103 [00:00<00:00, 1312.47it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  82%|████████▏ | 84/103 [00:00<00:00, 1309.71it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  83%|████████▎ | 85/103 [00:00<00:00, 1317.67it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  83%|████████▎ | 85/103 [00:00<00:00, 1315.45it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  83%|████████▎ | 86/103 [00:00<00:00, 1324.89it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  83%|████████▎ | 86/103 [00:00<00:00, 1322.27it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  84%|████████▍ | 87/103 [00:00<00:00, 1332.56it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  84%|████████▍ | 87/103 [00:00<00:00, 1329.17it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  85%|████████▌ | 88/103 [00:00<00:00, 1339.43it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  85%|████████▌ | 88/103 [00:00<00:00, 1336.69it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  86%|████████▋ | 89/103 [00:00<00:00, 1346.94it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  86%|████████▋ | 89/103 [00:00<00:00, 1344.82it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  87%|████████▋ | 90/103 [00:00<00:00, 1354.15it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  87%|████████▋ | 90/103 [00:00<00:00, 1351.93it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  88%|████████▊ | 91/103 [00:00<00:00, 1362.24it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  88%|████████▊ | 91/103 [00:00<00:00, 1359.57it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  89%|████████▉ | 92/103 [00:00<00:00, 1369.67it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  89%|████████▉ | 92/103 [00:00<00:00, 1365.15it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  90%|█████████ | 93/103 [00:00<00:00, 1374.87it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  90%|█████████ | 93/103 [00:00<00:00, 1372.73it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  91%|█████████▏| 94/103 [00:00<00:00, 1381.67it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  91%|█████████▏| 94/103 [00:00<00:00, 1379.47it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  92%|█████████▏| 95/103 [00:00<00:00, 1386.69it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  92%|█████████▏| 95/103 [00:00<00:00, 1384.51it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  93%|█████████▎| 96/103 [00:00<00:00, 1393.88it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  93%|█████████▎| 96/103 [00:00<00:00, 1391.73it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  94%|█████████▍| 97/103 [00:00<00:00, 1401.66it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  94%|█████████▍| 97/103 [00:00<00:00, 1397.37it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  95%|█████████▌| 98/103 [00:00<00:00, 1405.72it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 98/103 [00:00<00:00, 1403.61it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 99/103 [00:00<00:00, 1412.64it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 99/103 [00:00<00:00, 1410.60it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 100/103 [00:00<00:00, 1417.47it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  97%|█████████▋| 100/103 [00:00<00:00, 1415.02it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  98%|█████████▊| 101/103 [00:00<00:00, 1421.29it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  98%|█████████▊| 101/103 [00:00<00:00, 1419.09it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  99%|█████████▉| 102/103 [00:00<00:00, 1427.46it/s, Materializing param=pooler.dense.bias]
# Loading weights:  99%|█████████▉| 102/103 [00:00<00:00, 1425.17it/s, Materializing param=pooler.dense.bias]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1435.38it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1432.85it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1428.76it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [Query] List the differences of the 3q, 3s and 3m release ...
# [*] 동적 탐색 계획 수립: 80개 지점 정밀 분석 예정
#
# Scouting:   0%|          | 0/90 [00:00<?, ?it/s]
# Scouting:   1%|          | 1/90 [00:00<01:11,  1.25it/s]
# Scouting:   3%|▎         | 3/90 [00:00<00:22,  3.80it/s]
# Scouting:  10%|█         | 9/90 [00:01<00:06, 12.41it/s]
# Scouting:  13%|█▎        | 12/90 [00:01<00:06, 11.15it/s]
# Scouting:  16%|█▌        | 14/90 [00:01<00:06, 12.17it/s]
# Scouting:  18%|█▊        | 16/90 [00:01<00:05, 12.40it/s]
# Scouting:  20%|██        | 18/90 [00:01<00:06, 10.63it/s]
# Scouting:  22%|██▏       | 20/90 [00:02<00:06, 11.00it/s]
# Scouting:  24%|██▍       | 22/90 [00:02<00:05, 12.55it/s]
# Scouting:  28%|██▊       | 25/90 [00:02<00:04, 16.08it/s]
# Scouting:  30%|███       | 27/90 [00:02<00:03, 16.66it/s]
# Scouting:  32%|███▏      | 29/90 [00:02<00:04, 14.12it/s]
# Scouting:  34%|███▍      | 31/90 [00:02<00:04, 11.94it/s]
# Scouting:  37%|███▋      | 33/90 [00:02<00:04, 12.63it/s]
# Scouting:  39%|███▉      | 35/90 [00:03<00:04, 13.67it/s]
# Scouting:  41%|████      | 37/90 [00:03<00:03, 14.40it/s]
# Scouting:  43%|████▎     | 39/90 [00:03<00:04, 11.32it/s]
# Scouting:  46%|████▌     | 41/90 [00:03<00:04, 11.98it/s]
# Scouting:  48%|████▊     | 43/90 [00:03<00:04, 10.04it/s]
# Scouting:  50%|█████     | 45/90 [00:04<00:03, 11.74it/s]
# Scouting:  52%|█████▏    | 47/90 [00:04<00:03, 12.55it/s]
# Scouting:  54%|█████▍    | 49/90 [00:04<00:04,  8.42it/s]
# Scouting:  57%|█████▋    | 51/90 [00:04<00:03,  9.75it/s]
# Scouting:  59%|█████▉    | 53/90 [00:05<00:04,  7.97it/s]
# Scouting:  61%|██████    | 55/90 [00:05<00:03,  9.35it/s]
# Scouting:  63%|██████▎   | 57/90 [00:05<00:03,  9.11it/s]
# Scouting:  66%|██████▌   | 59/90 [00:05<00:02, 10.75it/s]
# Scouting:  68%|██████▊   | 61/90 [00:05<00:02, 10.66it/s]
# Scouting:  70%|███████   | 63/90 [00:06<00:03,  8.54it/s]
# Scouting:  72%|███████▏  | 65/90 [00:06<00:02,  9.22it/s]
# Scouting:  78%|███████▊  | 70/90 [00:06<00:01, 15.21it/s]
# Scouting:  81%|████████  | 73/90 [00:06<00:00, 17.60it/s]
# Scouting:  84%|████████▍ | 76/90 [00:06<00:00, 18.29it/s]
# Scouting:  88%|████████▊ | 79/90 [00:07<00:01,  8.78it/s]
# Scouting:  92%|█████████▏| 83/90 [00:07<00:00, 12.30it/s]
# Scouting:  96%|█████████▌| 86/90 [00:07<00:00,  9.70it/s]
# Scouting:  98%|█████████▊| 88/90 [00:08<00:00,  7.75it/s]
# Scouting: 100%|██████████| 90/90 [00:10<00:00,  3.11it/s]
# Scouting: 100%|██████████| 90/90 [00:10<00:00,  8.73it/s]
#   [Query] List me a timeline for when each version of the Vm...
# [*] 동적 탐색 계획 수립: 100개 지점 정밀 분석 예정
#
# Scouting:   0%|          | 0/108 [00:00<?, ?it/s]
# Scouting:   1%|          | 1/108 [00:00<01:19,  1.34it/s]
# Scouting:   3%|▎         | 3/108 [00:00<00:27,  3.78it/s]
# Scouting:   8%|▊         | 9/108 [00:01<00:07, 12.86it/s]
# Scouting:  12%|█▏        | 13/108 [00:01<00:05, 16.86it/s]
# Scouting:  15%|█▍        | 16/108 [00:01<00:09,  9.42it/s]
# Scouting:  19%|█▊        | 20/108 [00:02<00:08, 10.75it/s]
# Scouting:  23%|██▎       | 25/108 [00:02<00:05, 15.22it/s]
# Scouting:  26%|██▌       | 28/108 [00:02<00:04, 16.11it/s]
# Scouting:  29%|██▊       | 31/108 [00:02<00:06, 12.25it/s]
# Scouting:  31%|███       | 33/108 [00:02<00:05, 12.84it/s]
# Scouting:  32%|███▏      | 35/108 [00:03<00:06, 12.03it/s]
# Scouting:  34%|███▍      | 37/108 [00:03<00:05, 12.90it/s]
# Scouting:  37%|███▋      | 40/108 [00:03<00:04, 15.80it/s]
# Scouting:  39%|███▉      | 42/108 [00:03<00:04, 15.49it/s]
# Scouting:  41%|████      | 44/108 [00:03<00:05, 11.93it/s]
# Scouting:  43%|████▎     | 46/108 [00:04<00:06, 10.16it/s]
# Scouting:  44%|████▍     | 48/108 [00:04<00:05, 11.24it/s]
# Scouting:  46%|████▋     | 50/108 [00:04<00:04, 12.49it/s]
# Scouting:  49%|████▉     | 53/108 [00:04<00:03, 15.24it/s]
# Scouting:  51%|█████     | 55/108 [00:04<00:03, 14.95it/s]
# Scouting:  53%|█████▎    | 57/108 [00:04<00:04, 12.61it/s]
# Scouting:  56%|█████▋    | 61/108 [00:04<00:02, 16.11it/s]
# Scouting:  58%|█████▊    | 63/108 [00:05<00:03, 14.50it/s]
# Scouting:  60%|██████    | 65/108 [00:05<00:03, 11.40it/s]
# Scouting:  63%|██████▎   | 68/108 [00:05<00:02, 14.40it/s]
# Scouting:  67%|██████▋   | 72/108 [00:05<00:02, 17.05it/s]
# Scouting:  69%|██████▊   | 74/108 [00:05<00:01, 17.10it/s]
# Scouting:  70%|███████   | 76/108 [00:06<00:02, 12.47it/s]
# Scouting:  72%|███████▏  | 78/108 [00:06<00:02, 11.65it/s]
# Scouting:  74%|███████▍  | 80/108 [00:06<00:02, 13.08it/s]
# Scouting:  76%|███████▌  | 82/108 [00:06<00:01, 13.16it/s]
# Scouting:  79%|███████▊  | 85/108 [00:06<00:01, 14.03it/s]
# Scouting:  82%|████████▏ | 89/108 [00:06<00:00, 19.17it/s]
# Scouting:  85%|████████▌ | 92/108 [00:07<00:01, 14.87it/s]
# Scouting:  87%|████████▋ | 94/108 [00:07<00:00, 15.23it/s]
# Scouting:  89%|████████▉ | 96/108 [00:07<00:00, 14.04it/s]
# Scouting:  91%|█████████ | 98/108 [00:07<00:00, 14.84it/s]
# Scouting:  94%|█████████▎| 101/108 [00:07<00:00, 16.66it/s]
# Scouting:  96%|█████████▋| 104/108 [00:07<00:00, 19.17it/s]
# Scouting:  99%|█████████▉| 107/108 [00:08<00:00, 12.81it/s]
# Scouting: 100%|██████████| 108/108 [00:08<00:00, 12.62it/s]
#
# [Experiment] EU AI Act Analysis
#
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loading weights:   1%|          | 1/103 [00:00<00:00, 25115.59it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   1%|          | 1/103 [00:00<00:00, 1215.39it/s, Materializing param=embeddings.LayerNorm.bias]
# Loading weights:   2%|▏         | 2/103 [00:00<00:00, 1244.05it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   2%|▏         | 2/103 [00:00<00:00, 539.15it/s, Materializing param=embeddings.LayerNorm.weight]
# Loading weights:   3%|▎         | 3/103 [00:00<00:00, 680.78it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   3%|▎         | 3/103 [00:00<00:00, 366.54it/s, Materializing param=embeddings.position_embeddings.weight]
# Loading weights:   4%|▍         | 4/103 [00:00<00:00, 465.62it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   4%|▍         | 4/103 [00:00<00:00, 431.11it/s, Materializing param=embeddings.token_type_embeddings.weight]
# Loading weights:   5%|▍         | 5/103 [00:00<00:00, 494.51it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   5%|▍         | 5/103 [00:00<00:00, 488.95it/s, Materializing param=embeddings.word_embeddings.weight]
# Loading weights:   6%|▌         | 6/103 [00:00<00:00, 573.57it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   6%|▌         | 6/103 [00:00<00:00, 568.03it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.bias]
# Loading weights:   7%|▋         | 7/103 [00:00<00:00, 607.90it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   7%|▋         | 7/103 [00:00<00:00, 460.57it/s, Materializing param=encoder.layer.0.attention.output.LayerNorm.weight]
# Loading weights:   8%|▊         | 8/103 [00:00<00:00, 468.83it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   8%|▊         | 8/103 [00:00<00:00, 437.60it/s, Materializing param=encoder.layer.0.attention.output.dense.bias]
# Loading weights:   9%|▊         | 9/103 [00:00<00:00, 471.68it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:   9%|▊         | 9/103 [00:00<00:00, 462.10it/s, Materializing param=encoder.layer.0.attention.output.dense.weight]
# Loading weights:  10%|▉         | 10/103 [00:00<00:00, 466.44it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:  10%|▉         | 10/103 [00:00<00:00, 454.09it/s, Materializing param=encoder.layer.0.attention.self.key.bias]
# Loading weights:  11%|█         | 11/103 [00:00<00:00, 472.06it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:  11%|█         | 11/103 [00:00<00:00, 456.79it/s, Materializing param=encoder.layer.0.attention.self.key.weight]
# Loading weights:  12%|█▏        | 12/103 [00:00<00:00, 492.45it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:  12%|█▏        | 12/103 [00:00<00:00, 490.28it/s, Materializing param=encoder.layer.0.attention.self.query.bias]
# Loading weights:  13%|█▎        | 13/103 [00:00<00:00, 525.85it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:  13%|█▎        | 13/103 [00:00<00:00, 523.59it/s, Materializing param=encoder.layer.0.attention.self.query.weight]
# Loading weights:  14%|█▎        | 14/103 [00:00<00:00, 555.28it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:  14%|█▎        | 14/103 [00:00<00:00, 551.79it/s, Materializing param=encoder.layer.0.attention.self.value.bias]
# Loading weights:  15%|█▍        | 15/103 [00:00<00:00, 583.97it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:  15%|█▍        | 15/103 [00:00<00:00, 580.36it/s, Materializing param=encoder.layer.0.attention.self.value.weight]
# Loading weights:  16%|█▌        | 16/103 [00:00<00:00, 603.40it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:  16%|█▌        | 16/103 [00:00<00:00, 592.00it/s, Materializing param=encoder.layer.0.intermediate.dense.bias]
# Loading weights:  17%|█▋        | 17/103 [00:00<00:00, 609.51it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 17/103 [00:00<00:00, 576.05it/s, Materializing param=encoder.layer.0.intermediate.dense.weight]
# Loading weights:  17%|█▋        | 18/103 [00:00<00:00, 594.07it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  17%|█▋        | 18/103 [00:00<00:00, 584.88it/s, Materializing param=encoder.layer.0.output.LayerNorm.bias]
# Loading weights:  18%|█▊        | 19/103 [00:00<00:00, 569.28it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  18%|█▊        | 19/103 [00:00<00:00, 566.44it/s, Materializing param=encoder.layer.0.output.LayerNorm.weight]
# Loading weights:  19%|█▉        | 20/103 [00:00<00:00, 563.76it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  19%|█▉        | 20/103 [00:00<00:00, 551.44it/s, Materializing param=encoder.layer.0.output.dense.bias]
# Loading weights:  20%|██        | 21/103 [00:00<00:00, 572.66it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  20%|██        | 21/103 [00:00<00:00, 570.67it/s, Materializing param=encoder.layer.0.output.dense.weight]
# Loading weights:  21%|██▏       | 22/103 [00:00<00:00, 591.99it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  21%|██▏       | 22/103 [00:00<00:00, 574.00it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.bias]
# Loading weights:  22%|██▏       | 23/103 [00:00<00:00, 587.26it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  22%|██▏       | 23/103 [00:00<00:00, 583.42it/s, Materializing param=encoder.layer.1.attention.output.LayerNorm.weight]
# Loading weights:  23%|██▎       | 24/103 [00:00<00:00, 602.75it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  23%|██▎       | 24/103 [00:00<00:00, 600.54it/s, Materializing param=encoder.layer.1.attention.output.dense.bias]
# Loading weights:  24%|██▍       | 25/103 [00:00<00:00, 621.64it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  24%|██▍       | 25/103 [00:00<00:00, 620.02it/s, Materializing param=encoder.layer.1.attention.output.dense.weight]
# Loading weights:  25%|██▌       | 26/103 [00:00<00:00, 641.12it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  25%|██▌       | 26/103 [00:00<00:00, 639.53it/s, Materializing param=encoder.layer.1.attention.self.key.bias]
# Loading weights:  26%|██▌       | 27/103 [00:00<00:00, 660.33it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  26%|██▌       | 27/103 [00:00<00:00, 658.18it/s, Materializing param=encoder.layer.1.attention.self.key.weight]
# Loading weights:  27%|██▋       | 28/103 [00:00<00:00, 678.75it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  27%|██▋       | 28/103 [00:00<00:00, 677.07it/s, Materializing param=encoder.layer.1.attention.self.query.bias]
# Loading weights:  28%|██▊       | 29/103 [00:00<00:00, 697.39it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  28%|██▊       | 29/103 [00:00<00:00, 695.73it/s, Materializing param=encoder.layer.1.attention.self.query.weight]
# Loading weights:  29%|██▉       | 30/103 [00:00<00:00, 715.44it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  29%|██▉       | 30/103 [00:00<00:00, 713.68it/s, Materializing param=encoder.layer.1.attention.self.value.bias]
# Loading weights:  30%|███       | 31/103 [00:00<00:00, 733.45it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  30%|███       | 31/103 [00:00<00:00, 731.76it/s, Materializing param=encoder.layer.1.attention.self.value.weight]
# Loading weights:  31%|███       | 32/103 [00:00<00:00, 751.34it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  31%|███       | 32/103 [00:00<00:00, 749.61it/s, Materializing param=encoder.layer.1.intermediate.dense.bias]
# Loading weights:  32%|███▏      | 33/103 [00:00<00:00, 765.52it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  32%|███▏      | 33/103 [00:00<00:00, 761.01it/s, Materializing param=encoder.layer.1.intermediate.dense.weight]
# Loading weights:  33%|███▎      | 34/103 [00:00<00:00, 777.21it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  33%|███▎      | 34/103 [00:00<00:00, 774.53it/s, Materializing param=encoder.layer.1.output.LayerNorm.bias]
# Loading weights:  34%|███▍      | 35/103 [00:00<00:00, 791.99it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  34%|███▍      | 35/103 [00:00<00:00, 789.45it/s, Materializing param=encoder.layer.1.output.LayerNorm.weight]
# Loading weights:  35%|███▍      | 36/103 [00:00<00:00, 807.61it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  35%|███▍      | 36/103 [00:00<00:00, 804.97it/s, Materializing param=encoder.layer.1.output.dense.bias]
# Loading weights:  36%|███▌      | 37/103 [00:00<00:00, 822.32it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  36%|███▌      | 37/103 [00:00<00:00, 819.69it/s, Materializing param=encoder.layer.1.output.dense.weight]
# Loading weights:  37%|███▋      | 38/103 [00:00<00:00, 837.37it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  37%|███▋      | 38/103 [00:00<00:00, 834.71it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.bias]
# Loading weights:  38%|███▊      | 39/103 [00:00<00:00, 851.80it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  38%|███▊      | 39/103 [00:00<00:00, 848.75it/s, Materializing param=encoder.layer.2.attention.output.LayerNorm.weight]
# Loading weights:  39%|███▉      | 40/103 [00:00<00:00, 865.62it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  39%|███▉      | 40/103 [00:00<00:00, 861.92it/s, Materializing param=encoder.layer.2.attention.output.dense.bias]
# Loading weights:  40%|███▉      | 41/103 [00:00<00:00, 878.73it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  40%|███▉      | 41/103 [00:00<00:00, 875.94it/s, Materializing param=encoder.layer.2.attention.output.dense.weight]
# Loading weights:  41%|████      | 42/103 [00:00<00:00, 891.65it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  41%|████      | 42/103 [00:00<00:00, 888.80it/s, Materializing param=encoder.layer.2.attention.self.key.bias]
# Loading weights:  42%|████▏     | 43/103 [00:00<00:00, 905.18it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  42%|████▏     | 43/103 [00:00<00:00, 902.48it/s, Materializing param=encoder.layer.2.attention.self.key.weight]
# Loading weights:  43%|████▎     | 44/103 [00:00<00:00, 918.00it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  43%|████▎     | 44/103 [00:00<00:00, 915.24it/s, Materializing param=encoder.layer.2.attention.self.query.bias]
# Loading weights:  44%|████▎     | 45/103 [00:00<00:00, 930.06it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  44%|████▎     | 45/103 [00:00<00:00, 927.28it/s, Materializing param=encoder.layer.2.attention.self.query.weight]
# Loading weights:  45%|████▍     | 46/103 [00:00<00:00, 942.92it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  45%|████▍     | 46/103 [00:00<00:00, 939.67it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 955.12it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 952.36it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 967.80it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 964.85it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 978.71it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 975.89it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 991.03it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 988.31it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 1003.01it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 999.72it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 1014.50it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 1011.71it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1026.41it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1023.53it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1037.00it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1034.05it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1047.95it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1045.10it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1059.00it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1055.60it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1069.54it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1066.74it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1080.55it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1077.52it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# ...
# Loading weights:  45%|████▍     | 46/103 [00:00<00:00, 915.21it/s, Materializing param=encoder.layer.2.attention.self.value.bias]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 930.52it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  46%|████▌     | 47/103 [00:00<00:00, 927.97it/s, Materializing param=encoder.layer.2.attention.self.value.weight]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 943.25it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  47%|████▋     | 48/103 [00:00<00:00, 940.68it/s, Materializing param=encoder.layer.2.intermediate.dense.bias]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 955.21it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  48%|████▊     | 49/103 [00:00<00:00, 952.46it/s, Materializing param=encoder.layer.2.intermediate.dense.weight]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 967.41it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  49%|████▊     | 50/103 [00:00<00:00, 964.85it/s, Materializing param=encoder.layer.2.output.LayerNorm.bias]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 979.47it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|████▉     | 51/103 [00:00<00:00, 976.35it/s, Materializing param=encoder.layer.2.output.LayerNorm.weight]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 990.85it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  50%|█████     | 52/103 [00:00<00:00, 988.26it/s, Materializing param=encoder.layer.2.output.dense.bias]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1002.77it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  51%|█████▏    | 53/103 [00:00<00:00, 1000.22it/s, Materializing param=encoder.layer.2.output.dense.weight]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1013.97it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  52%|█████▏    | 54/103 [00:00<00:00, 1011.27it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.bias]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1025.13it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  53%|█████▎    | 55/103 [00:00<00:00, 1022.49it/s, Materializing param=encoder.layer.3.attention.output.LayerNorm.weight]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1036.44it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  54%|█████▍    | 56/103 [00:00<00:00, 1033.28it/s, Materializing param=encoder.layer.3.attention.output.dense.bias]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1046.78it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  55%|█████▌    | 57/103 [00:00<00:00, 1044.07it/s, Materializing param=encoder.layer.3.attention.output.dense.weight]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1057.68it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  56%|█████▋    | 58/103 [00:00<00:00, 1055.02it/s, Materializing param=encoder.layer.3.attention.self.key.bias]
# Loading weights:  57%|█████▋    | 59/103 [00:00<00:00, 1067.85it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  57%|█████▋    | 59/103 [00:00<00:00, 1065.11it/s, Materializing param=encoder.layer.3.attention.self.key.weight]
# Loading weights:  58%|█████▊    | 60/103 [00:00<00:00, 1078.25it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  58%|█████▊    | 60/103 [00:00<00:00, 1075.57it/s, Materializing param=encoder.layer.3.attention.self.query.bias]
# Loading weights:  59%|█████▉    | 61/103 [00:00<00:00, 1088.86it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  59%|█████▉    | 61/103 [00:00<00:00, 1085.75it/s, Materializing param=encoder.layer.3.attention.self.query.weight]
# Loading weights:  60%|██████    | 62/103 [00:00<00:00, 1098.65it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  60%|██████    | 62/103 [00:00<00:00, 1095.92it/s, Materializing param=encoder.layer.3.attention.self.value.bias]
# Loading weights:  61%|██████    | 63/103 [00:00<00:00, 1108.88it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  61%|██████    | 63/103 [00:00<00:00, 1106.19it/s, Materializing param=encoder.layer.3.attention.self.value.weight]
# Loading weights:  62%|██████▏   | 64/103 [00:00<00:00, 1118.50it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  62%|██████▏   | 64/103 [00:00<00:00, 1115.72it/s, Materializing param=encoder.layer.3.intermediate.dense.bias]
# Loading weights:  63%|██████▎   | 65/103 [00:00<00:00, 1128.22it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  63%|██████▎   | 65/103 [00:00<00:00, 1125.50it/s, Materializing param=encoder.layer.3.intermediate.dense.weight]
# Loading weights:  64%|██████▍   | 66/103 [00:00<00:00, 1138.11it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  64%|██████▍   | 66/103 [00:00<00:00, 1134.84it/s, Materializing param=encoder.layer.3.output.LayerNorm.bias]
# Loading weights:  65%|██████▌   | 67/103 [00:00<00:00, 1147.20it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  65%|██████▌   | 67/103 [00:00<00:00, 1144.34it/s, Materializing param=encoder.layer.3.output.LayerNorm.weight]
# Loading weights:  66%|██████▌   | 68/103 [00:00<00:00, 1156.76it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  66%|██████▌   | 68/103 [00:00<00:00, 1154.11it/s, Materializing param=encoder.layer.3.output.dense.bias]
# Loading weights:  67%|██████▋   | 69/103 [00:00<00:00, 1165.91it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  67%|██████▋   | 69/103 [00:00<00:00, 1163.17it/s, Materializing param=encoder.layer.3.output.dense.weight]
# Loading weights:  68%|██████▊   | 70/103 [00:00<00:00, 1175.03it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  68%|██████▊   | 70/103 [00:00<00:00, 1172.20it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.bias]
# Loading weights:  69%|██████▉   | 71/103 [00:00<00:00, 1184.12it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  69%|██████▉   | 71/103 [00:00<00:00, 1180.81it/s, Materializing param=encoder.layer.4.attention.output.LayerNorm.weight]
# Loading weights:  70%|██████▉   | 72/103 [00:00<00:00, 1192.26it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  70%|██████▉   | 72/103 [00:00<00:00, 1189.38it/s, Materializing param=encoder.layer.4.attention.output.dense.bias]
# Loading weights:  71%|███████   | 73/103 [00:00<00:00, 1201.05it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  71%|███████   | 73/103 [00:00<00:00, 1198.29it/s, Materializing param=encoder.layer.4.attention.output.dense.weight]
# Loading weights:  72%|███████▏  | 74/103 [00:00<00:00, 1209.36it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  72%|███████▏  | 74/103 [00:00<00:00, 1206.55it/s, Materializing param=encoder.layer.4.attention.self.key.bias]
# Loading weights:  73%|███████▎  | 75/103 [00:00<00:00, 1217.67it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  73%|███████▎  | 75/103 [00:00<00:00, 1214.92it/s, Materializing param=encoder.layer.4.attention.self.key.weight]
# Loading weights:  74%|███████▍  | 76/103 [00:00<00:00, 1225.79it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  74%|███████▍  | 76/103 [00:00<00:00, 1223.42it/s, Materializing param=encoder.layer.4.attention.self.query.bias]
# Loading weights:  75%|███████▍  | 77/103 [00:00<00:00, 1235.62it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  75%|███████▍  | 77/103 [00:00<00:00, 1233.87it/s, Materializing param=encoder.layer.4.attention.self.query.weight]
# Loading weights:  76%|███████▌  | 78/103 [00:00<00:00, 1246.21it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  76%|███████▌  | 78/103 [00:00<00:00, 1244.49it/s, Materializing param=encoder.layer.4.attention.self.value.bias]
# Loading weights:  77%|███████▋  | 79/103 [00:00<00:00, 1256.90it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  77%|███████▋  | 79/103 [00:00<00:00, 1255.19it/s, Materializing param=encoder.layer.4.attention.self.value.weight]
# Loading weights:  78%|███████▊  | 80/103 [00:00<00:00, 1266.97it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  78%|███████▊  | 80/103 [00:00<00:00, 1265.18it/s, Materializing param=encoder.layer.4.intermediate.dense.bias]
# Loading weights:  79%|███████▊  | 81/103 [00:00<00:00, 1277.34it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  79%|███████▊  | 81/103 [00:00<00:00, 1275.61it/s, Materializing param=encoder.layer.4.intermediate.dense.weight]
# Loading weights:  80%|███████▉  | 82/103 [00:00<00:00, 1287.93it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  80%|███████▉  | 82/103 [00:00<00:00, 1286.25it/s, Materializing param=encoder.layer.4.output.LayerNorm.bias]
# Loading weights:  81%|████████  | 83/103 [00:00<00:00, 1298.55it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  81%|████████  | 83/103 [00:00<00:00, 1296.87it/s, Materializing param=encoder.layer.4.output.LayerNorm.weight]
# Loading weights:  82%|████████▏ | 84/103 [00:00<00:00, 1308.47it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  82%|████████▏ | 84/103 [00:00<00:00, 1306.76it/s, Materializing param=encoder.layer.4.output.dense.bias]
# Loading weights:  83%|████████▎ | 85/103 [00:00<00:00, 1318.80it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  83%|████████▎ | 85/103 [00:00<00:00, 1317.14it/s, Materializing param=encoder.layer.4.output.dense.weight]
# Loading weights:  83%|████████▎ | 86/103 [00:00<00:00, 1329.09it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  83%|████████▎ | 86/103 [00:00<00:00, 1327.37it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.bias]
# Loading weights:  84%|████████▍ | 87/103 [00:00<00:00, 1339.32it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  84%|████████▍ | 87/103 [00:00<00:00, 1337.61it/s, Materializing param=encoder.layer.5.attention.output.LayerNorm.weight]
# Loading weights:  85%|████████▌ | 88/103 [00:00<00:00, 1343.41it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  85%|████████▌ | 88/103 [00:00<00:00, 1340.38it/s, Materializing param=encoder.layer.5.attention.output.dense.bias]
# Loading weights:  86%|████████▋ | 89/103 [00:00<00:00, 1350.49it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  86%|████████▋ | 89/103 [00:00<00:00, 1347.58it/s, Materializing param=encoder.layer.5.attention.output.dense.weight]
# Loading weights:  87%|████████▋ | 90/103 [00:00<00:00, 1357.04it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  87%|████████▋ | 90/103 [00:00<00:00, 1353.96it/s, Materializing param=encoder.layer.5.attention.self.key.bias]
# Loading weights:  88%|████████▊ | 91/103 [00:00<00:00, 1363.91it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  88%|████████▊ | 91/103 [00:00<00:00, 1361.01it/s, Materializing param=encoder.layer.5.attention.self.key.weight]
# Loading weights:  89%|████████▉ | 92/103 [00:00<00:00, 1370.43it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  89%|████████▉ | 92/103 [00:00<00:00, 1367.49it/s, Materializing param=encoder.layer.5.attention.self.query.bias]
# Loading weights:  90%|█████████ | 93/103 [00:00<00:00, 1377.22it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  90%|█████████ | 93/103 [00:00<00:00, 1374.34it/s, Materializing param=encoder.layer.5.attention.self.query.weight]
# Loading weights:  91%|█████████▏| 94/103 [00:00<00:00, 1384.11it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  91%|█████████▏| 94/103 [00:00<00:00, 1381.28it/s, Materializing param=encoder.layer.5.attention.self.value.bias]
# Loading weights:  92%|█████████▏| 95/103 [00:00<00:00, 1390.31it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  92%|█████████▏| 95/103 [00:00<00:00, 1387.31it/s, Materializing param=encoder.layer.5.attention.self.value.weight]
# Loading weights:  93%|█████████▎| 96/103 [00:00<00:00, 1396.94it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  93%|█████████▎| 96/103 [00:00<00:00, 1394.07it/s, Materializing param=encoder.layer.5.intermediate.dense.bias]
# Loading weights:  94%|█████████▍| 97/103 [00:00<00:00, 1403.31it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  94%|█████████▍| 97/103 [00:00<00:00, 1400.37it/s, Materializing param=encoder.layer.5.intermediate.dense.weight]
# Loading weights:  95%|█████████▌| 98/103 [00:00<00:00, 1409.83it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  95%|█████████▌| 98/103 [00:00<00:00, 1406.95it/s, Materializing param=encoder.layer.5.output.LayerNorm.bias]
# Loading weights:  96%|█████████▌| 99/103 [00:00<00:00, 1416.26it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  96%|█████████▌| 99/103 [00:00<00:00, 1413.41it/s, Materializing param=encoder.layer.5.output.LayerNorm.weight]
# Loading weights:  97%|█████████▋| 100/103 [00:00<00:00, 1422.20it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  97%|█████████▋| 100/103 [00:00<00:00, 1419.21it/s, Materializing param=encoder.layer.5.output.dense.bias]
# Loading weights:  98%|█████████▊| 101/103 [00:00<00:00, 1428.29it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  98%|█████████▊| 101/103 [00:00<00:00, 1425.52it/s, Materializing param=encoder.layer.5.output.dense.weight]
# Loading weights:  99%|█████████▉| 102/103 [00:00<00:00, 1434.39it/s, Materializing param=pooler.dense.bias]
# Loading weights:  99%|█████████▉| 102/103 [00:00<00:00, 1431.46it/s, Materializing param=pooler.dense.bias]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1440.67it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1437.94it/s, Materializing param=pooler.dense.weight]
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1433.05it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#   [Query] Given a virtual ai assistant in the healthcare dom...
# [*] 동적 탐색 계획 수립: 100개 지점 정밀 분석 예정
#
# Scouting:   0%|          | 0/8 [00:00<?, ?it/s]
# Scouting:  12%|█▎        | 1/8 [00:00<00:04,  1.56it/s]
# Scouting:  25%|██▌       | 2/8 [00:00<00:02,  2.78it/s]
# Scouting:  50%|█████     | 4/8 [00:00<00:00,  5.65it/s]
# Scouting: 100%|██████████| 8/8 [00:03<00:00,  2.24it/s]
# Scouting: 100%|██████████| 8/8 [00:03<00:00,  2.41it/s]
#
# ✅ 실험이 성공적으로 완료되었습니다.

# %%
if os.path.exists(log_path):
    # CSV 로드 (utf-8-sig 인코딩 적용)
    df = pd.read_csv(log_path)
    
    display(Markdown("## 📊 Experiment Summary"))
    
    # 기본 통계 및 테이블 출력
    display(df.tail(10)) # 최근 실행 결과 10건
    
    # 실험별 평균 소요 시간 계산
    if 'latency' in df.columns:
        avg_latency = df.groupby('experiment_name')['latency'].apply(
            lambda x: x.str.replace('s', '').astype(float).mean()
        )
        display(Markdown("### 🕒 Experiment Inference Time (Latency)"))
        print(avg_latency)
else:
    print("⚠️ 결과 로그 파일을 찾을 수 없습니다. 실험이 정상적으로 완료되었는지 확인하세요.")
# Out:
# ## 📊 Experiment Summary
#                           timestamp                   experiment_name  \
# 0               2026-02-11 11:01:32              VMware Documentation
# 1               2026-02-11 11:01:54              VMware Documentation
# 2               2026-02-11 11:02:52                EU AI Act Analysis
# 3               2026-02-11 11:03:13                EU AI Act Analysis
# 4               2026-02-11 11:03:30                EU AI Act Analysis
# 5               2026-02-11 11:04:38            EU National Parks File
# 6               2026-02-11 11:05:22            EU National Parks File
# 7               2026-02-11 11:05:36            EU National Parks File
# 8               2026-02-11 11:06:50  AI Act + Top generative use case
# 9  reranker model (cohere reranker)                               NaN
#
#                                                query  \
# 0  List the differences of the 3q, 3s and 3m rele...
# 1  List me a timeline for when each version of th...
# 2         How many articles are there in the AI Act?
# 3  Summarize the requirements for high-risk AI sy...
# 4  What are the prohibited AI practices according...
# 5  List me all national parks sorted by their hig...
# 6  List me all national parks where I can see bro...
# 7  Give me a table of all the national parks in s...
# 8  Given a virtual ai assistant in the healthcare...
# 9                                                NaN
#
#                                               answer  latency  \
# 0  Based on the provided evidence, the difference...  212.89s
# 1  Based on the provided evidence, here is a time...   21.87s
# 2       The AI Act contains a total of 103 articles.   55.62s
# 3  The requirements for high-risk AI systems are ...   20.62s
# 4  The prohibited AI practices according to Artic...    16.8s
# 5  Based on the provided evidence, the national p...   65.51s
# 6  Based on the provided evidence, the following ...   43.99s
# 7  Based on the provided evidence, the national p...   14.32s
# 8  The AI Act regulations relevant to a virtual A...   71.56s
# 9                                                NaN      NaN
#
#                               source_files
# 0                               vmware.txt
# 1                               vmware.txt
# 2                                aiact.txt
# 3                                aiact.txt
# 4                                aiact.txt
# 5                 nationalparks_europe.txt
# 6                 nationalparks_europe.txt
# 7                 nationalparks_europe.txt
# 8  aiact.txt, top_generative_use_cases.txt
# 9                                      NaN
# ### 🕒 Experiment Inference Time (Latency)
# experiment_name
# AI Act + Top generative use case     71.560000
# EU AI Act Analysis                   31.013333
# EU National Parks File               41.273333
# VMware Documentation                117.380000
# Name: latency, dtype: float64

# %%
if os.path.exists(log_path):
    df = pd.read_csv(log_path)
    if not df.empty:
        latest_exp = df['experiment_name'].iloc[0]
        display(Markdown(f"### 🔍 Experiment Output: **{latest_exp}**"))
        
        subset = df[df['experiment_name'] == latest_exp]
        for _, row in subset.iterrows():
            display(Markdown(f"---"))
            display(Markdown(f"**Query:** {row['query']}"))
            display(Markdown(f"**Answer:** {row['answer']}"))
            display(Markdown(f"*InferTime: {row.get('latency', 'N/A')} | Source: {row.get('source_files', 'N/A')}*"))
# Out:
# ### 🔍 Experiment Output: **VMware Documentation**
# ---
# **Query:** List the differences of the 3q, 3s and 3m release in a table.
# **Answer:** Based on the provided evidence, the differences between the 3q, 3s, and 3m releases are as follows:  ### ESXi 7.0 Update 3q - **Build Details**:   - Download Filename: VMware-ESXi-7.0U3q-21686933-depot.zip   - Build: 21686933   - Download Size: 379.4 MB   - md5sum: 9cd52571752b939637f80b351daace94   - sha256checksum: 8c7892af03254259db28e7f2982be2802dcf66bdb2fc92e15a06fe7 e7835b692   - Host Reboot Required: Yes   - Virtual Machine Migration or Shutdown Required: Yes  ### ESXi 7.0 Update 3s - **Build Details**:   - Download Filename: VMware-ESXi-7.0U3s-21686933-depot.zip   - Build: 21686933   - Download Size: 379.4 MB   - md5sum: 9cd52571752b939637f80b351daace94   - sha256checksum: 8c7892af03254259db28e7f2982be2802dcf66bdb2fc92e15a06fe7 e7835b692   - Host Reboot Required: Yes   - Virtual Machine Migration or Shutdown Required: Yes  ### ESXi 7.0 Update 3m - **Build Details**:   - Download Filename: VMware-ESXi-7.0U3m-21686933-depot.zip   - Build: 21686933   - Download Size: 379.4 MB   - md5sum: 9cd52571752b939637f80b351daace94   - sha256checksum: 8c7892af03254259db28e7f2982be2802dcf66bdb2fc92e15a06fe7 e7835b692   - Host Reboot Required: Yes   - Virtual Machine Migration or Shutdown Required: Yes  ### Components - **ESXi Component - core ESXi VIBs**:   - Bulletin: ESXi_7.0.3-0.90.21686933   - Category: Bugfix   - Severity: Critical - **ESXi Install/Upgrade Component**:   - Bulletin: esx-update_7.0.3-0.90.21686933   - Category: Bugfix   - Severity: Critical - **Broadcom NetXtreme I ESX VMKAPI ethernet driver**:   - Bulletin: Broadcom-ntg3_4.1.9.0-5vmw.703.0.90.21686933   - Category: Bugfix   - Severity: Critical  ### Rollup Bulletin - **Bulletin ID**: ESXi70U3q-21686933, ESXi70U3s-21686933, ESXi70U3m-21686933 - **Category**: Bugfix - **Severity**: Critical  ### Image Profiles - **ESXi-7.0U3q-21686933-standard**:   - Build: For build information, see Patches Contained in this Release.   - Vendor: VMware, Inc.   - Release Date: May 03, 2023   - Acceptance Level: PartnerSupported   - Affected Hardware: N/A   - Affected Software: N/A   - Affected VIBs: List of VIBs   - PRs Fixed: 3164897, 3182870   - Related CVE numbers: N/A - **ESXi-7.0U3q-21686933-no-tools**:   - Build: For build information, see Patches Contained in this Release.   - Vendor: VMware, Inc.   - Release Date: May 03, 2023   - Acceptance Level: PartnerSupported   - Affected Hardware: N/A   - Affected Software: N/A   - Affected VIBs: List of VIBs   - PRs Fixed: 3164897, 3182870   - Related CVE numbers: N/A  ### ESXi Image - **Name and Version**: ESXi70U3q-21686933, ESXi70U3s-21686933, ESXi70U3m-21686933 - **Release Date**: May 03, 2023 - **Category**: Bugfix - **Affected Components**:   - ESXi Component - core ESXi VIBs   - ESXi Install/Upgrade Component   - Broadcom NetXtreme I ESX VMKAPI ethernet - **PRs Fixed**: 3164897, 3182870 - **Related CVE numbers**: N/A  ### Known Issues from Previous Releases - **vSAN Issues**:   - If you change the preferred site in a VMware vSAN Stretched Cluster, some objects might incorrectly appear as compliant. - **vSphere Cluster Services Issues**:   - You see compatibility issues in new vCLS VMs deployed in vSphere 7.0 Update 3 environment. - **Installation, Upgrade, and Migration Issues**:   - The vCenter Upgrade/Migration pre-checks fail with "Unexpected error 87".   - Problems upgrading to vSphere 7.0 with pre-existing CIM providers.   - Installation of 7.0 Update 1 drivers on ESXi 7.0 hosts might fail.   - UEFI booting of ESXi hosts might stop with an error during an update to ESXi 7.0 Update 2 from an earlier version of ESXi 7.0.   - If legacy VIBs are in use on an ESXi host, vSphere Lifecycle Manager cannot extract a desired software specification to seed to a new cluster.   - You see a short burst of log messages in the syslog.log after every ESXi boot.   - You see warning messages for missing VIBs in vSphere Quick Boot compatibility check reports.   - Auto bootstrapping a cluster that you manage with a vSphere Lifecy ...
# *InferTime: 212.89s | Source: vmware.txt*
# ---
# **Query:** List me a timeline for when each version of the Vmware vCenter was released.
# **Answer:** Based on the provided evidence, here is a timeline of VMware vCenter Server versions and their release dates:  | Version | Release Date | |---------|--------------| | vCenter Server 7.0 | Not specified in the evidence | | vCenter Server 7.0.0a | Not specified in the evidence | | vCenter Server 7.0.0b | Not specified in the evidence | | vCenter Server 7.0.0c | Not specified in the evidence | | vCenter Server 7.0.0d | Not specified in the evidence | | vCenter Server 7.0 Update 1 | Not specified in the evidence | | vCenter Server 7.0 Update 1a | Not specified in the evidence | | vCenter Server 7.0 Update 1b | Not specified in the evidence | | vCenter Server 7.0 Update 1c | Not specified in the evidence | | vCenter Server 7.0 Update 1d | Not specified in the evidence | | vCenter Server 7.0 Update 2 | Not specified in the evidence | | vCenter Server 7.0 Update 2a | Not specified in the evidence | | vCenter Server 7.0 Update 2b | Not specified in the evidence | | vCenter Server 7.0 Update 2c | Not specified in the evidence | | vCenter Server 7.0 Update 2d | Not specified in the evidence | | vCenter Server 7.0 Update 2e | Not specified in the evidence | | vCenter Server 7.0 Update 3 | Not specified in the evidence | | vCenter Server 7.0 Update 3a | Not specified in the evidence | | vCenter Server 7.0 Update 3c | Not specified in the evidence | | vCenter Server 7.0 Update 3d | Not specified in the evidence | | vCenter Server 7.0 Update 3e | Not specified in the evidence | | vCenter Server 7.0 Update 3f | Not specified in the evidence | | vCenter Server 7.0 Update 3g | Not specified in the evidence | | vCenter Server 7.0 Update 3i | Not specified in the evidence | | vCenter Server 7.0 Update 3j | Not specified in the evidence | | vCenter Server 7.0 Update 3k | Not specified in the evidence | | vCenter Server 7.0 Update 3l | Not specified in the evidence | | vCenter Server 7.0 Update 3m | Not specified in the evidence | | vCenter Server 7.0 Update 3n | Not specified in the evidence | | vCenter Server 7.0 Update 3o | Not specified in the evidence | | vCenter Server 7.0 Update 3p | Not specified in the evidence |  The evidence provided does not contain specific release dates for the vCenter Server versions listed. The table above includes the versions mentioned in the evidence, but their release dates are not specified.
# *InferTime: 21.87s | Source: vmware.txt*
